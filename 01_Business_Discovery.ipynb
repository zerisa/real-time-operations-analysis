# %% [markdown]
# # Real-Time Operations Optimization
#
# ## Business Analysis Portfolio
#
# Author:
# Erisa Zifle
#
# Role:
# Business Analyst / Real Time Analyst

# %% [markdown]
# # Business Context
# ConnectPlus Contact Center is experiencing declining Service Levels despite maintaining a stable number of scheduled agents. Management has requested an investigation to identify operational bottlenecks and recommend improvements without increasing headcount

# %% [markdown]
# # Business Problem
# Service Level has dropped from 86% to 72% over the last three months. Customer waiting times have increased, customer satisfaction has decreased, and management is unsure of the underlying cause.

# %% [markdown]
# # Project Objective
# Identify the operational factors affecting Service Level and recommend actionable improvements based on data analysis.

# %% [markdown]
# # Business Questions
# 1. Why is Service Level decreasing?
#
# 2. Which hours experience the highest workload?
#
# 3. Does Occupancy impact SLA?
#
# 4. Are staffing levels appropriate?
#
# 5. Is Average Handle Time increasing?
#
# 6. Which queues generate the longest waiting times?
#
# 7. Which KPI has the strongest relationship with SLA?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
